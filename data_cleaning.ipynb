# %%
import pandas as pd
cchs=pd.read_csv("/Users/shashank/Desktop/SpringboardDatascience/data_cleanup/CCHS_2012.csv")

# %%
cchs.head()
# Out:
#    CASEID   verdate  adm_prx  adm_n09  adm_n10  adm_n11  adm_rno  pmkproxy  \
# 0       1  20130913        2        1        1        6        1         6
# 1       2  20130913        2        6        1        6        2         6
# 2       3  20130913        2        6        1        6        3         6
# 3       4  20130913        2        6        1        6        4         6
# 4       5  20130913        2        6        1        6        5         6
#
#    geogprv  geodpmf   ...     dhhgl12  dhhglvg  dhhghsz  hwt_4  hwtghtm  \
# 0       35    35935   ...           0        3        2      1    1.575
# 1       59    59932   ...           0        1        1      1    1.905
# 2       35    35970   ...           1        4        5      3    1.803
# 3       46    46903   ...           0        1        1      3    1.727
# 4       24    24914   ...           0        5        2      3    1.803
#
#    hwtgwtk  hwtgbmi  hwtgisw  hwtdcol    wts_m
# ...

# %%
cchs.shape
# Out:
# (124929, 36)

# %%
cchs.describe()
# Out:
#               CASEID     verdate        adm_prx        adm_n09        adm_n10  \
# count  124929.000000    124929.0  124929.000000  124929.000000  124929.000000
# mean    62465.000000  20130913.0       1.978284       4.248309       1.352496
# std     36064.040227         0.0       0.145756       2.106146       1.372670
# min         1.000000  20130913.0       1.000000       1.000000       1.000000
# 25%     31233.000000  20130913.0       2.000000       2.000000       1.000000
# 50%     62465.000000  20130913.0       2.000000       6.000000       1.000000
# 75%     93697.000000  20130913.0       2.000000       6.000000       1.000000
# max    124929.000000  20130913.0       2.000000       9.000000       9.000000
#
#             adm_n11        adm_rno       pmkproxy        geogprv  \
# count  124929.00000  124929.000000  124929.000000  124929.000000
# mean        5.62943   62465.000000       5.740685      36.247541
# std         1.42846   36064.040227       1.125396      14.220773
# ...

# %%
cchs2=pd.read_csv("/Users/shashank/Desktop/SpringboardDatascience/data_cleanup/CCHS_2012.csv",na_values=['NA'])

# %%
#finding null columns
cchs[pd.isnull(cchs['adm_prx'])]
# Out:
# Empty DataFrame
# Columns: [CASEID, verdate, adm_prx, adm_n09, adm_n10, adm_n11, adm_rno, pmkproxy, geogprv, geodpmf, geodbcha, sdcgcb12, sdc_5a_1, sdcdfols, dhh_own, sdcglhm, sdcfimm, sdcgres, sdcgcgt, sdc_8, sdcg9, dhhgage, dhh_sex, dhhgms, dhhgle5, dhhg611, dhhgl12, dhhglvg, dhhghsz, hwt_4, hwtghtm, hwtgwtk, hwtgbmi, hwtgisw, hwtdcol, wts_m]
# Index: []
#
# [0 rows x 36 columns]

# %%
#dropping columns
s1=cchs.drop(["adm_rno","pmkproxy"],axis=1)
clear
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-759538033d14> in <module>()
#       1 #dropping columns
#       2 s1=cchs.drop(["adm_rno","pmkproxy"],axis=1)
# ----> 3 clear
#
# NameError: name 'clear' is not defined

# %%
#transform data, drop duplicates values

s2=cchs.drop_duplicates()

# %%
#replace values in whole dataframe
s3=cchs.replace(1,7)

# %%
#changing index
cchs.rename(index={0:"adm_prx"})
# Out:
#          CASEID   verdate  adm_prx  adm_n09  adm_n10  adm_n11  adm_rno  \
# adm_prx       1  20130913        2        1        1        6        1
# 1             2  20130913        2        6        1        6        2
# 2             3  20130913        2        6        1        6        3
# 3             4  20130913        2        6        1        6        4
# 4             5  20130913        2        6        1        6        5
# 5             6  20130913        2        2        1        6        6
# 6             7  20130913        2        2        1        6        7
# 7             8  20130913        1        1        1        6        8
# 8             9  20130913        2        6        1        6        9
# 9            10  20130913        2        2        1        6       10
# 10           11  20130913        2        2        2        2       11
# 11           12  20130913        2        2        2        2       12
# ...

# %%
#set index
cchs.set_index('adm_n11')
# Out:
#          CASEID   verdate  adm_prx  adm_n09  adm_n10  adm_rno  pmkproxy  \
# adm_n11
# 6             1  20130913        2        1        1        1         6
# 6             2  20130913        2        6        1        2         6
# 6             3  20130913        2        6        1        3         6
# 6             4  20130913        2        6        1        4         6
# 6             5  20130913        2        6        1        5         6
# 6             6  20130913        2        2        1        6         6
# 6             7  20130913        2        2        1        7         6
# 6             8  20130913        1        1        1        8         6
# 6             9  20130913        2        6        1        9         6
# 6            10  20130913        2        2        1       10         6
# 2            11  20130913        2        2        2       11         6
# 2            12  20130913        2        2        2       12         6
# ...

# %%
#create a new column
cchs["b_column"]=1

# %%
cchs.head()
# Out:
#    CASEID   verdate  adm_prx  adm_n09  adm_n10  adm_n11  adm_rno  pmkproxy  \
# 0       1  20130913        2        1        1        6        1         6
# 1       2  20130913        2        6        1        6        2         6
# 2       3  20130913        2        6        1        6        3         6
# 3       4  20130913        2        6        1        6        4         6
# 4       5  20130913        2        6        1        6        5         6
#
#    geogprv  geodpmf    ...     dhhglvg  dhhghsz  hwt_4  hwtghtm  hwtgwtk  \
# 0       35    35935    ...           3        2      1    1.575    65.25
# 1       59    59932    ...           1        1      1    1.905    99.00
# 2       35    35970    ...           4        5      3    1.803    77.40
# 3       46    46903    ...           1        1      3    1.727    85.50
# 4       24    24914    ...           5        2      3    1.803    81.00
#
#    hwtgbmi  hwtgisw  hwtdcol    wts_m  b_column
# ...

# %%
#rename variables
cchs_rename=cchs.rename(columns={"adm_prx":"adm","pmkproxy":"pmk"})
cchs_rename.head()
# Out:
#    CASEID   verdate  adm  adm_n09  adm_n10  adm_n11  adm_rno  pmk  geogprv  \
# 0       1  20130913    2        1        1        6        1    6       35
# 1       2  20130913    2        6        1        6        2    6       59
# 2       3  20130913    2        6        1        6        3    6       35
# 3       4  20130913    2        6        1        6        4    6       46
# 4       5  20130913    2        6        1        6        5    6       24
#
#    geodpmf    ...     dhhglvg  dhhghsz  hwt_4  hwtghtm  hwtgwtk  hwtgbmi  \
# 0    35935    ...           3        2      1    1.575    65.25    26.30
# 1    59932    ...           1        1      1    1.905    99.00    27.28
# 2    35970    ...           4        5      3    1.803    77.40    23.81
# 3    46903    ...           1        1      3    1.727    85.50    28.67
# 4    24914    ...           5        2      3    1.803    81.00    24.92
#
#    hwtgisw  hwtdcol    wts_m  b_column
# ...

# %%
#drop missing values
cchs.dropna()
# Out:
#         CASEID   verdate  adm_prx  adm_n09  adm_n10  adm_n11  adm_rno  \
# 0            1  20130913        2        1        1        6        1
# 1            2  20130913        2        6        1        6        2
# 2            3  20130913        2        6        1        6        3
# 3            4  20130913        2        6        1        6        4
# 4            5  20130913        2        6        1        6        5
# 5            6  20130913        2        2        1        6        6
# 6            7  20130913        2        2        1        6        7
# 7            8  20130913        1        1        1        6        8
# 8            9  20130913        2        6        1        6        9
# 9           10  20130913        2        2        1        6       10
# 10          11  20130913        2        2        2        2       11
# 11          12  20130913        2        2        2        2       12
# ...

# %%
cchs.fillna(1)
# Out:
#         CASEID   verdate  adm_prx  adm_n09  adm_n10  adm_n11  adm_rno  \
# 0            1  20130913        2        1        1        6        1
# 1            2  20130913        2        6        1        6        2
# 2            3  20130913        2        6        1        6        3
# 3            4  20130913        2        6        1        6        4
# 4            5  20130913        2        6        1        6        5
# 5            6  20130913        2        2        1        6        6
# 6            7  20130913        2        2        1        6        7
# 7            8  20130913        1        1        1        6        8
# 8            9  20130913        2        6        1        6        9
# 9           10  20130913        2        2        1        6       10
# 10          11  20130913        2        2        2        2       11
# 11          12  20130913        2        2        2        2       12
# ...
